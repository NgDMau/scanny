# %%
from os import listdir
from os.path import isfile, join
mypath = 'images/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
stringlist = " ".join(onlyfiles)
print(stringlist)
# Out:
# 8b8.jpg IMG_3175.JPG girl3.jpg

# %%
with open('test.txt','r') as file:
    text = file.readlines()
    return text
# Out:
#   File "<ipython-input-15-8183d5e2cd16>", line 3
#     return text
#     ^
# SyntaxError: 'return' outside function

# %%
from PIL import Image
import numpy as np
import sys
img = 'images/8b8.jpg'
ary = np.asarray(Image.open(img))
# Split the three channels
r,g,b = np.split(ary,3,axis=2)
r=r.reshape(-1)
g=r.reshape(-1)
b=r.reshape(-1)

# Standard RGB to grayscale 
bitmap = list(map(lambda x: 0.299*x[0]+0.587*x[1]+0.114*x[2], 
    zip(r,g,b)))
bitmap = np.array(bitmap).reshape([ary.shape[0], ary.shape[1]])
bitmap = np.dot((bitmap > 128).astype(float),255)
im = Image.fromarray(bitmap.astype(np.uint8))
im.save('road.bmp')

# %%
img = Image.open('road.bmp')
new_img = img.resize( (256, 256) )
new_img.save( 'road.png', 'png')

# %%
import os
fname = 'images/IMG_3175.JPG'
with open(fname,'rb') as fb:
    strng = fb.read()
print(os.path.getsize(fname))
# Out:
# 3178134

# %%
def changeTime():
    call(["./changeTime.sh"])

# %%
if(data[0] == "Time"):
    tempList = data[1].split("-")
    minute = tempList[len(tempList)-1]
    hour   = tempList[len(tempList)-2]
    time   = hour + " " + minute
    fileTime = open('outputTime.txt','w')
    fileTime.write(time)
    fileTime.close()
    thread_changeTime = Thread(target = changeTime)
    thread_changeTime.start()
    thread_changeTime.join()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7840afc8a9d> in <module>()
# ----> 1 if(data[0] == "Time"):
#       2     tempList = data[1].split("-")
#       3     minute = tempList[len(tempList)-1]
#       4     hour   = tempList[len(tempList)-2]
#       5     time   = hour + " " + minute
#
# NameError: name 'data' is not defined

# %%
with open('images/8b8.jpg','rb') as file:
    strng = file.read()
    print(strng)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc2\x00\x11\x08\x01w\x01\xf4\x03\x01"`=\xb8\x90,\xe6\xaf-\n\xb1y\xe4e\xd2\xe4\x8by\xd1\xa9\xde\x89\xcez\x97W\xbc\xe7M,\xde\xeb\xeb\xdd\x84\xe0\xf7\xcd/\xcf\xf4E\xb9\xeb[\xc3G\xa4\xf2\x9d\xef?M\x84\x9e\x84\xa1n\xb70\xea\xddT\xc6\xe0\xab\x9f\xe5\xbdg\x8c\xc5h}%\xf1\xa6\xfa\xa1/nbY\xed\x9c\xd5\xfb\x1c\xf9|\xdfa\xbe$\xbe\x8d;\xe7\x99|\xdd\x1a\xe7_[\t\xca#\xc7\x8f>n\xb6W\xcf\xf5w\xd3)\xc2gPF\x01\x8d\xcb\x95\xe6:~G\xb7\xcb]%\x8f\xc0\xed\xcb\xaa\x8c|\xe3